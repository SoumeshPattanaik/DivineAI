# %% [markdown]
# <a href="https://colab.research.google.com/github/SoumeshPattanaik/DivineAI/blob/main/Flight.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# Read a dataset with missing values
flights = pd.read_csv("https://raw.githubusercontent.com/roberthryniewicz/datasets/master/airline-dataset/flights/flights.csv")

# %%
# Select the rows that have at least one missing value
flights[flights.isnull().any(axis=1)].head()
# Out:
#    Year  Month  DayofMonth  ...  NASDelay  SecurityDelay  LateAircraftDelay
# 0  2008      1           3  ...       NaN            NaN                NaN
# 1  2008      1           3  ...       NaN            NaN                NaN
# 2  2008      1           3  ...       NaN            NaN                NaN
# 3  2008      1           3  ...       NaN            NaN                NaN
# 4  2008      1           3  ...       0.0            0.0               32.0
#
# [5 rows x 29 columns]
